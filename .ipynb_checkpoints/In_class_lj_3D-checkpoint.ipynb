# %%
import numpy as np
from numpy.linalg import norm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import sympy as sp

# %%
def r_mag(atom_1, atom_2):
    norm_1 = np.linalg.norm(atom_1)
    norm_2 = np.linalg.norm(atom_2)
    r = np.sqrt((norm_2 - norm_1)**2)
    return r

def Vlj_3d(r_mag, epsilon=1.0, sigma=1.0):
    potential = 4*epsilon*((sigma/r_mag)**12 - (sigma/r_mag)**6)
    return potential

A = np.array([1.0, 0.0, 0.0]) 
B = np.array([0.0, 0.0, 0.0])
atoms = [A, B]
r = r_mag(atoms[0], atoms[1])    
# This here is for a single point, but lets sketch out this potential for mulitple radii
radii = np.linspace(0.99,2.5)
V_E = Vlj_3d(radii)
plt.plot(radii, V_E);plt.xlabel("Bond Length");plt.ylabel("Potenital Energy");plt.title("Lennard Jones Potential")
plt.show()

# %%
def Flj_3d(atom, atom_index, atoms, epsilon=1.0, sigma=1.0):
    force = np.zeros((3,1))
    for i in range(len(atoms)):
        if i != atom_index:
            force_part = np.zeros((3,1))
            r = r_mag(atom, atoms[i])
            for j in range(3):
                force_part[j] = ((atom[j] - atoms[i][j]) * ((24*sigma*(epsilon**6)) / (r**8))
                *(1-(2*((sigma/r)**6))))
            force -= force_part
    return force #Our force is 3 dimensional
    
A = np.array([1.0, 0.0, 0.0]) 
B = np.array([0.0, 0.0, 0.0])
atoms = [A,B]
F = Flj_3d(atoms[1],1, atoms)

# %%
def Verlet_Algorithm(atoms, vel_atoms, m_atoms, end_t, h):
    t = [0]
    x = [[atoms[0][0]], [atoms[1][0]]]#list that keeps track of all the positions of every atoms over the length of time
    y = [[atoms[0][1]], [atoms[1][1]]]
    z = [[atoms[0][2]], [atoms[1][2]]]
    x_vel = [[vel_atoms[0][0]], [vel_atoms[1][0]]]
    y_vel = [[vel_atoms[0][1]], [vel_atoms[1][1]]]
    z_vel = [[vel_atoms[0][2]], [vel_atoms[1][2]]]
    while t[-1] < end_t:    
        # Before we begin, lets find the force at the positions we 
        # curently are and store them for later use
        F_k_0 = np.zeros((len(atoms), 3))
        atoms_new = np.zeros((len(atoms), 3))
        # Step 1: Calculate the new positions
        for i in range(len(atoms)):
            F = Flj_3d(atoms[i],i, atoms)
            for j in range(3):
                F_k_0[i][j] = F[j]
                atoms_new[i][j] = atoms[i][j] + (h*vel_atoms[i][j]) + (((h**2)*F[j])/(2*m_atoms[i])) 
            x[i].append(atoms_new[i][0])
            y[i].append(atoms_new[i][1])
            z[i].append(atoms_new[i][2])
        for i in range(len(atoms)): #now we modify 
            for j in range(3):
                atoms[i][j] = atoms_new[i][j]
        # Step 2: Evaluate the Forces at these new positions
        F_k_1 = np.zeros((len(atoms), 3))
        vel_new = np.zeros((len(atoms), 3))
        # Step 3: Calculate the new velocities 
        for i in range(len(atoms)):
            F = Flj_3d(atoms[i],i, atoms)
            for j in range(3):
                F_k_1[i][j] = F[j]
                vel_new[i][j] = vel_atoms[i][j] + ((h/(2*m_atoms[i]))*(F_k_0[i][j]+F_k_1[i][j]))
            x_vel[i].append(vel_new[i][0])
            y_vel[i].append(vel_new[i][1])
            z_vel[i].append(vel_new[i][2])
        for i in range(len(atoms)): #now we modify 
            for j in range(3):
                vel_atoms[i][j] = vel_new[i][j]
        t.append(t[-1]+h)
        
    return t, np.array([x, y, z]), np.array([x_vel, y_vel, z_vel])
A = np.array([1.0, 0.0, 0.0]) 
B = np.array([0.0, 0.0, 0.0])
A_vel = np.array([0.0, 0.0, 0.0])
B_vel = np.array([0.0, 0.0, 0.0])
atoms = [A,B]
vel_atoms = [A_vel, B_vel]
m_atoms = [1.0, 1.0]
end_t = 3
t, pos, vel = Verlet_Algorithm(atoms, vel_atoms, m_atoms, end_t, 0.02)
r_x = np.sqrt((pos[1][0] - pos[0][0])**2)
print(r_x)
plt.plot(t, r_x); plt.xlabel("time"); plt.ylabel("$r_{AB}$")
plt.show()
# Out:
# [1.00000000e+00 1.00480000e+00 1.01929216e+00 1.04375473e+00
#  1.07865739e+00 1.12467027e+00 1.18267682e+00 1.25379077e+00
#  1.33937750e+00 1.44108028e+00 1.56085179e+00 1.70099167e+00
#  1.86419058e+00 2.05358195e+00 2.27280210e+00 2.52606004e+00
#  2.81821834e+00 3.15488643e+00 3.54252834e+00 3.98858680e+00
#  4.50162612e+00 5.09149666e+00 5.76952394e+00 6.54872608e+00
#  7.44406376e+00 8.47272746e+00 9.65446753e+00 1.10119734e+01
#  1.25713091e+01 1.43624140e+01 1.64196772e+01 1.87825982e+01
#  2.14965451e+01 2.46136257e+01 2.81936879e+01 3.23054689e+01
#  3.70279149e+01 4.24516968e+01 4.86809514e+01 5.58352802e+01
#  6.40520464e+01 7.34890119e+01 8.43273664e+01 9.67752063e+01
#  1.11071530e+02 1.27490828e+02 1.46348349e+02 1.68006158e+02
#  1.92880086e+02 2.21447711e+02 2.54257533e+02 2.91939499e+02
#  3.35217103e+02 3.84921276e+02 4.42006337e+02 5.07568320e+02
#  5.82866015e+02 6.69345137e+02 7.68666086e+02 8.82735823e+02
#  1.01374449e+03 1.16420745e+03 1.33701359e+03 1.53548079e+03
#  1.76341963e+03 2.02520652e+03 2.32586778e+03 2.67117610e+03
#  3.06776140e+03 3.52323811e+03 4.04635140e+03 4.64714504e+03
#  5.33715426e+03 6.12962725e+03 7.03977947e+03 8.08508587e+03
#  9.28561631e+03 1.06644210e+04 1.22479729e+04 1.40666764e+04
#  1.61554504e+04 1.85543995e+04 2.13095834e+04 2.44739018e+04
#  2.81081094e+04 3.22819832e+04 3.70756614e+04 4.25811827e+04
#  4.89042532e+04 5.61662757e+04 6.45066811e+04 7.40856052e+04
#  8.50869632e+04 9.77219814e+04 1.12233252e+05 1.28899392e+05
#  1.48040390e+05 1.70023754e+05 1.95271564e+05 2.24268579e+05
#  2.57571541e+05 2.95819867e+05 3.39747925e+05 3.90199134e+05
#  4.48142156e+05 5.14689498e+05 5.91118869e+05 6.78897713e+05
#  7.79711383e+05 8.95495502e+05 1.02847312e+06 1.18119742e+06
#  1.35660070e+06 1.55805070e+06 1.78941527e+06 2.05513660e+06
#  2.36031654e+06 2.71081455e+06 3.11336019e+06 3.57568234e+06
#  4.10665758e+06 4.71648063e+06 5.41686010e+06 6.22124328e+06
#  7.14507432e+06 8.20609077e+06 9.42466416e+06 1.08241911e+07
#  1.24315425e+07 1.42775795e+07 1.63977460e+07 1.88327492e+07
#  2.16293412e+07 2.48412166e+07 2.85300433e+07 3.27666468e+07
#  3.76323699e+07 4.32206345e+07 4.96387353e+07 5.70098998e+07
#  6.54756543e+07 7.51985415e+07 8.63652406e+07 9.91901523e+07
#  1.13919515e+08 1.30836132e+08 1.50264803e+08 1.72578558e+08
#  1.98205822e+08 2.27638637e+08 2.61442114e+08]
